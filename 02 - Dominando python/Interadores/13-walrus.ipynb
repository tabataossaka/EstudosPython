# %% [markdown]
# Walrus
# - Esse operador é usado para atribuiçãoes de variáveis dentro de expressões.
# - E usado com o operador :=
# - permite que você atribua um valor a uma variável enquanto avalia a expressão.

# %%
numeros = [5, 12, 7, 20, 3, 15]

# %%
# Using the walrus operator to filter numbers greater than 10
numeros_maiores_que_10 = [n for n in numeros if (maior := n) > 10]
numeros_maiores_que_10
# Out:
# [12, 20, 15]

# %%
linhas_processadas = []
with open("Texto.txt", "r", encoding="utf-8") as arquivo:
    for linha in arquivo:
        if (linha_limpa := linha.strip()):
            linhas_processadas.append(linha_limpa)

# %%
linhas_processadas
# Out:
# ['Olá Mundo',
#  'Este é uma linha de teste',
#  'Python é fácil',
#  'Ruby é interessante']
