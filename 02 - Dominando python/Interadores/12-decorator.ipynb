# %% [markdown]
# Decorator
# - Modificam ou estendem o comportamento de funcoes existentes de forma reutilizavel
# -Adicionam funcionalidadea a funções existentes sem modificar seu código diretamente
