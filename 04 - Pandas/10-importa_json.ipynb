# %%
import json
import pandas as pd

# %%
df = pd.read_json("Dados/receitas.json", encoding="utf-8")
df
# Out:
#                                             receitas
# 0  {'titulo': 'Bolo de Chocolate', 'tempo_preparo...
# 1  {'titulo': 'Salada Caesar', 'tempo_preparo': '...
# 2  {'titulo': 'Pasta ao Pesto', 'tempo_preparo': ...

# %%
df_receitas = pd.json_normalize(
    df['receitas'],
    'ingredientes',
    ['titulo', 'tempo_preparo', 'porcoes']
)

"""
"Dentro da coluna receitas, pegue a lista ingredientes e, 
para cada ingrediente, traga também titulo, tempo_preparo 
e porcoes que estão no mesmo objeto."
"""

# %%
df_receitas
# Out:
#          ingrediente  quantidade             titulo tempo_preparo porcoes
# 0   Farinha de Trigo   2 xícaras  Bolo de Chocolate    45 minutos       8
# 0             Açúcar    1 xícara  Bolo de Chocolate    45 minutos       8
# 0               Ovos   3 xícaras  Bolo de Chocolate    45 minutos       8
# 0              Leite    1 xícara  Bolo de Chocolate    45 minutos       8
# 0           Manteiga  1/2 xícara  Bolo de Chocolate    45 minutos       8
# 1      Alface romana    1 cabeça      Salada Caesar    20 minutos       4
# 1           Croutons    1 xícara      Salada Caesar    20 minutos       4
# 1    Queijo parmesão  1/2 xícara      Salada Caesar    20 minutos       4
# 1       Molho caesar  1/4 xícara      Salada Caesar    20 minutos       4
# 2              Massa        200g     Pasta ao Pesto    30 minutos       2
# 2  Manjericão fresco  1/2 xícara     Pasta ao Pesto    30 minutos       2
# 2    Azeite de oliva  1/3 xícara     Pasta ao Pesto    30 minutos       2
# ...
