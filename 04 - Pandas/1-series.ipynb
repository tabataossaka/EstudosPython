# %% [markdown]
# - Uma Series do Pandas possui um índice com rótulos explícitos (nomeados), enquanto um Array (como o do NumPy) é indexado apenas por posições numéricas inteiras (0, 1, 2...).

# %%
import pandas as pd

# %%
#
dados = [10, 20, 30, 40, 50]
serie = pd.Series(dados)
serie
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
type(serie)
# Out:
# pandas.Series

# %%
#1-Criando uma Series com dados de vendas mensais
vendas_mensais = pd.Series(
    [2000, 2500, 3000, 2800, 3500, 4000, 4500, 5000, 4800, 5200, 6000, 7000],
    index=['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
)

# %%
vendas_mensais
# Out:
# Jan    2000
# Fev    2500
# Mar    3000
# Abr    2800
# Mai    3500
# Jun    4000
# Jul    4500
# Ago    5000
# Set    4800
# Out    5200
# Nov    6000
# Dez    7000
# dtype: int64

# %%
#2-Calculando e exibir a média de vendas
media_vendas = vendas_mensais.mean()
media_vendas
# Out:
# np.float64(4191.666666666667)

# %%
#3-Identificando o mês com maior venda
mes_maior_venda = vendas_mensais.idxmax()
mes_maior_venda
# Out:
# 'Dez'

# %%
#4-Exibir as vendas acima da média
vendas_acima_media = vendas_mensais[vendas_mensais > media_vendas]
vendas_acima_media
# Out:
# Jul    4500
# Ago    5000
# Set    4800
# Out    5200
# Nov    6000
# Dez    7000
# dtype: int64
