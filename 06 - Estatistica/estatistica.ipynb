# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.5'

# %% [markdown]
# ### Defindo os dados

# %%
dict_metrics = {"idade":[15, 18, 25, 26, 40, 40, 58, 60],
                "altura":[160, 165, 149, 168, 172, 174, 174, 178]}

# %%
type(dict_metrics)
# Out:
# dict

# %%
df = pd.DataFrame(dict_metrics)

# %%
df
# Out:
#    idade  altura
# 0     15     160
# 1     18     165
# 2     25     149
# 3     26     168
# 4     40     172
# 5     40     174
# 6     58     174
# 7     60     178

# %% [markdown]
# ### Medidas de Posição
# - Média: Soma de todos os valores dividida pelo número de valores. É a medida mais comum de tendência central. Pode ser sensível a valores extremos.
# - Mediana: É o valor do meio quando os dados estão ordenados. Não sofre por valores extremos. É útil em distribuições assimétricas.
# - Moda: É o valor que ocorre com maior frequência. É útil em dados categóricos ou quando deseja-se identificar valores com maior frequência

# %%
df["idade"]
# Out:
# 0    15
# 1    18
# 2    25
# 3    26
# 4    40
# 5    40
# 6    58
# 7    60
# Name: idade, dtype: int64

# %%
df.idade
# Out:
# 0    15
# 1    18
# 2    25
# 3    26
# 4    40
# 5    40
# 6    58
# 7    60
# Name: idade, dtype: int64

# %%
print(f"Media de Idade: {df['idade'].mean()}")
print(f"Media de Altura: {df['altura'].mean()}")
# Out:
# Media de Idade: 35.25
# Media de Altura: 167.5

# %%
print(f"Mediana de Idade: {df['idade'].median()}")
print(f"Mediana de Altura: {df['altura'].median()}")
# Out:
# Mediana de Idade: 33.0
# Mediana de Altura: 170.0

# %%
print(f"Moda de Idade: {df['idade'].mode()}")
print(f"Moda de Altura: {df['altura'].mode()}")
# Out:
# Moda de Idade: 0    40
# Name: idade, dtype: int64
# Moda de Altura: 0    174
# Name: altura, dtype: int64

# %% [markdown]
# ### Medidas de Dispersão
# - Variância: É a média dos quadrados entre cada valor e a média. Informa quão distantes os valores estão da média.
# - Desvio Padrão: É a raiz quadrada da variância. Expressa a dispersão em termos da mesma unidade dos dados.
# - Coeficiente de Variação: É o desvio padrão dividido pela média, expresso em porcentagem. Indica a variabilidade relativa dos dados em relação a média.

# %%
print(f"Variância de idade: {df['idade'].var()}") # Variância de Idade
print(f"Variância de altura: {df['altura'].var()}") # Variância de Altura
# Out:
# Variância de idade: 296.2142857142857
# Variância de altura: 88.57142857142857

# %%
print(f"Desvio padrão de idade: {df['idade'].std()}") # Desvio padrão de Idade
print(f"Desvio padrão de altura: {df['altura'].std()}") # Desvio padrão de Altura
# Out:
# Desvio padrão de idade: 17.210876959477854
# Desvio padrão de altura: 9.411239481143202

# %%
# Coeficiente de variação - idade
df["idade"].std() / df["idade"].mean() * 100
# Out:
# np.float64(48.82518286376696)

# %%
# Coeficiente de variação - altura
df["altura"].std() / df["altura"].mean() * 100
# Out:
# np.float64(5.618650436503405)

# %% [markdown]
# ### Medidas de Forma (Distribuição dos Dados)
# - Assimetria: Indica o grau e direção da distorção da distribuição em relação à média. Se positiva, indica a cauda direita da distribuição mais longa, já o oposta indica a cauda esquerda mais longa.
# - Curtose: Mede o pico ou "pontuação" da distribuição. Uma curtose alta indica uma distribuição mais concentrada, já o oposto indica uma distribuição mais achatada

# %%
df
# Out:
#    idade  altura
# 0     15     160
# 1     18     165
# 2     25     149
# 3     26     168
# 4     40     172
# 5     40     174
# 6     58     174
# 7     60     178

# %%
# Assimetria de idade positiva (valores maiores estão mais espalhados)
print(f"Assimetria de idade: {df['idade'].skew()}")

# Assimetria de altura negativa (valores maiores estão mais próximos)
print(f"Assimetria de altura: {df['altura'].skew()}")
# Out:
# Assimetria de idade: 0.44254516049230713
# Assimetria de altura: -1.1359101638062434

# %%
# Curtose de idade negativa (dados mais espalhados)
print(f"Curtose de idade: {df['idade'].kurtosis()}")

# Curtose de altura positiva (dados mais concentrados na média)
print(f"Curtose de altura: {df['altura'].kurtosis()}")
# Out:
# Curtose de idade: -1.3083027995345171
# Curtose de altura: 1.064502601456815

# %%
df.describe()
# Out:
#            idade      altura
# count   8.000000    8.000000
# mean   35.250000  167.500000
# std    17.210877    9.411239
# min    15.000000  149.000000
# 25%    23.250000  163.750000
# 50%    33.000000  170.000000
# 75%    44.500000  174.000000
# max    60.000000  178.000000

# %% [markdown]
# ### Correlação
# - Mede a relação entre duas variáveis, se positiva (aumentam juntas) ou negativa (uma aumenta enquanto outra diminui) ou não há uma correlação.
# - Ajuda a selecionar características relevantes para os modelos, melhorando a precisão e a interpretabilidade.

# %% [markdown]
# ### Índices de Correlação
# - Coeficiente de Pearson: Mede a relação linear entre duas variáveis, variando de -1 a 1 e 0 para nenhuma correlação.
# - Coeficiente de Spearman: É útil quando os dados não tem uma relação linear clara ou quando as variáveis não são numericamente escalonáveis.
# - Pearson para relação linear e variáveis contínuas e Spearman para relação não linear, ordinais ou com outliers.

# %%
df.corr(method='pearson')
# Out:
#            idade    altura
# idade   1.000000  0.740852
# altura  0.740852  1.000000

# %%
df.corr(method='spearman')
# Out:
#            idade    altura
# idade   1.000000  0.909639
# altura  0.909639  1.000000

# %%
df["idade"].corr(df["altura"], method="pearson")
# Out:
# np.float64(0.7408519382898473)

# %%
pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.18.1-cp314-cp314-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: numpy<2.8,>=2.0.0 in c:\Users\tabat\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scipy) (2.5.2)
# Downloading scipy-1.18.1-cp314-cp314-win_amd64.whl (37.4 MB)
#    ---------------------------------------- 0.0/37.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/37.4 MB ? eta -:--:--
#    ---------------------------------------- 0.3/37.4 MB ? eta -:--:--
#     --------------------------------------- 0.5/37.4 MB 967.3 kB/s eta 0:00:39
#     --------------------------------------- 0.8/37.4 MB 1.0 MB/s eta 0:00:37
#     --------------------------------------- 0.8/37.4 MB 1.0 MB/s eta 0:00:37
#    - -------------------------------------- 1.0/37.4 MB 937.1 kB/s eta 0:00:39
#    - -------------------------------------- 1.0/37.4 MB 937.1 kB/s eta 0:00:39
#    - -------------------------------------- 1.3/37.4 MB 831.9 kB/s eta 0:00:44
#    - -------------------------------------- 1.6/37.4 MB 852.1 kB/s eta 0:00:43
#    - -------------------------------------- 1.6/37.4 MB 852.1 kB/s eta 0:00:43
#    - -------------------------------------- 1.8/37.4 MB 844.4 kB/s eta 0:00:43
#    -- ------------------------------------- 2.1/37.4 MB 886.4 kB/s eta 0:00:40
#    ---------------------------------------  36.4/37.4 MB 790.1 kB/s eta 0:00:02
#    ---------------------------------------  36.4/37.4 MB 790.1 kB/s eta 0:00:02
#    ---------------------------------------  36.4/37.4 MB 790.1 kB/s eta 0:00:02
#    ---------------------------------------  36.7/37.4 MB 772.7 kB/s eta 0:00:01
#    ---------------------------------------  36.7/37.4 MB 772.7 kB/s eta 0:00:01
#    ---------------------------------------  37.0/37.4 MB 771.2 kB/s eta 0:00:01
#    ---------------------------------------  37.2/37.4 MB 772.6 kB/s eta 0:00:01
#    ---------------------------------------- 37.4/37.4 MB 768.1 kB/s  0:00:44
# Installing collected packages: scipy
# Successfully installed scipy-1.18.1
# Note: you may need to restart the kernel to use updated packages.

# %%
df["idade"].corr(df["altura"], method="spearman")
# Out:
# np.float64(0.9096385542168675)

# %% [markdown]
# ### Histograma

# %%
df["idade"].hist()
# Out:
# <Axes: >

# %%
df["altura"].hist()
# Out:
# <Axes: >

# %%
df["idade"].plot.box()
# Out:
# <Axes: >

# %%
df["altura"].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# ### Gráfico de Dispersão (Scatter Plot)

# %%
df.plot.scatter(x="idade", y="altura")
# Out:
# <Axes: xlabel='idade', ylabel='altura'>

# %% [markdown]
# ### Gráfico de Barras

# %%
dic_vendas = {"categoria":["eletrodomésticos", "games", "livros", "casa"],
              "valor":[20000, 50000, 10000, 200000],
              "quantidade":[200, 500, 300, 1500]}

# %%
df_vendas = pd.DataFrame(dic_vendas)

# %%
df_vendas
# Out:
#           categoria   valor  quantidade
# 0  eletrodomésticos   20000         200
# 1             games   50000         500
# 2            livros   10000         300
# 3              casa  200000        1500

# %%
df_vendas.dtypes
# Out:
# categoria       str
# valor         int64
# quantidade    int64
# dtype: object

# %%
df_vendas.plot.bar(x="categoria", y="valor")
# Out:
# <Axes: xlabel='categoria'>

# %%
df_vendas.sort_values("valor", ascending=True).plot.bar(x="categoria", y="valor")
# Out:
# <Axes: xlabel='categoria'>

# %%
df_vendas.sort_values("quantidade", ascending=False).plot.barh(x="categoria", y="quantidade")
# Out:
# <Axes: ylabel='categoria'>

# %% [markdown]
# ### Gráfico de Linha

# %%
dic_faturamento = {"data":["2020-01-01", "2021-01-01", "2022-01-01", "2023-01-01", "2024-01-01"],
                   "valor":["100000", "200000", "150000", "300000", "350000"]}

# %%
df_faturamento = pd.DataFrame(dic_faturamento)

# %%
df_faturamento
# Out:
#          data   valor
# 0  2020-01-01  100000
# 1  2021-01-01  200000
# 2  2022-01-01  150000
# 3  2023-01-01  300000
# 4  2024-01-01  350000

# %%
df_faturamento.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   data    5 non-null      str
#  1   valor   5 non-null      str
# dtypes: str(2)
# memory usage: 212.0 bytes

# %%
df_faturamento.dtypes
# Out:
# data     str
# valor    str
# dtype: object

# %%
df_faturamento["data"] =pd.to_datetime(df_faturamento["data"])

# %%
df_faturamento.dtypes
# Out:
# data     datetime64[us]
# valor               str
# dtype: object

# %%
df_faturamento["valor"] = pd.to_numeric(df_faturamento["valor"])

# %%
df_faturamento.dtypes
# Out:
# data     datetime64[us]
# valor             int64
# dtype: object

# %%
df_faturamento.plot.line(x="data", y="valor")
# Out:
# <Axes: xlabel='data'>
